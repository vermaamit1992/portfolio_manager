# %%
# calculation of beta =  covariance of stock with market/ variance of market

# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
stocks = ['TCS.NS', '^BSESN']  # preferred stock and Sensex
new_data = pd.DataFrame()
for t in stocks:
    new_data[t] = wb.DataReader(t, data_source='yahoo', start = '2012-1-1', end='2018-1-1')['Adj Close']

# %%
(new_data/new_data.iloc[0] * 100).plot(figsize=(8,5))
plt.show()

# %%
log_returns= np.log(new_data/new_data.shift(1))

# %%
cov_stknmkt = log_returns.cov() * 250                   # covariance matrix of stock with market
cov_stknmkt
# Out:
#           TCS.NS    ^BSESN
# TCS.NS  0.083250  0.031899
# ^BSESN  0.031899  0.048948

# %%
cov_with_mkt= cov_stknmkt.iloc[0,1]                  # covariance of stock with market
cov_with_mkt
# Out:
# 0.03189871551736916

# %%
mkt_var= log_returns['^BSESN'].var() * 250           # variance of market
mkt_var
# Out:
# 0.04894809807087466

# %%
beta_f_stk = cov_
